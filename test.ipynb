# %%
review = {
    "username": "john_doe",
    "rating": 4.5,
    "metrics": {
        "speed": 0,
        "clean": 0,
        "support": 0,
        "price": 0,
        "safety": 0
    },
    "likes": 0,
    "date": "2024-06-15"
}
